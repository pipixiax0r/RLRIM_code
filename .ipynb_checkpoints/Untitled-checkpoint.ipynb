# %%
import pandas as pd
import seaborn as sns

# %%
df = pd.read_csv('karate_seeds1_blockers1.csv')

# %%
df.head()
# Out:
#    rewards  infected
# 0 -29.6875      24.3
# 1 -31.7500      26.8
# 2 -26.2000      23.0
# 3 -30.9000      26.3
# 4 -23.7875      22.6

# %%
sns.lineplot(data=df.drop('rewards', axis=1))
# Out:
# <AxesSubplot:>

# %%
sns.lineplot(data=df.drop('infected', axis=1))
# Out:
# <AxesSubplot:>
